# %% [markdown]
# # Analyze trained model

# %% [markdown]
# ## Set up

# %%
# autoreload
# %load_ext autoreload
# %autoreload 2
# jupyter black formatter
# %load_ext jupyter_black

import subprocess
import os
import sys

gitroot_path = subprocess.check_output(
    ["git", "rev-parse", "--show-toplevel"], universal_newlines=True
)

os.chdir(os.path.join(gitroot_path[:-1], "pirnns"))
print("Working directory: ", os.getcwd())

sys_dir = os.path.dirname(os.getcwd())
sys.path.append(sys_dir)
print("Directory added to path: ", sys_dir)
sys.path.append(os.getcwd())
print("Directory added to path: ", os.getcwd())
# Out:
# Working directory:  /home/facosta/pirnns/pirnns
# Directory added to path:  /home/facosta/pirnns
# Directory added to path:  /home/facosta/pirnns/pirnns

# %% [markdown]
# ## Load the trained model

# %%
import torch
import yaml

from pirnns.rnns.rnn import RNN, RNNLightning
from pirnns.rnns.coupled_rnn import CoupledRNN, CoupledRNNLightning
import torch.nn as nn
import glob

model_type = "vanilla"  # or "coupled" depending on your run
run_id = "20250821_003413"  # Update this to your actual run ID

run_dir = f"logs/checkpoints/{model_type}_{run_id}"
config_path = f"{run_dir}/config_{run_id}.yaml"

with open(config_path, "r") as f:
    config = yaml.safe_load(f)

checkpoint_files = glob.glob(f"{run_dir}/best-model-*.ckpt")
print(f"Loading Lightning checkpoint from: {checkpoint_files[0]}")

# Create the correct model based on type
if model_type == "vanilla":
    model = RNN(
        input_size=config["input_size"],
        hidden_size=config["hidden_size"],
        output_size=config["num_place_cells"],  # Updated parameter name
        alpha=config["alpha"],
        activation=getattr(nn, config["activation"]),
    )

    rnn_lightning = RNNLightning.load_from_checkpoint(
        checkpoint_files[0],
        model=model,
        learning_rate=config["learning_rate"],
        weight_decay=config["weight_decay"],
        step_size=config["step_size"],
        gamma=config["gamma"],
    )
elif model_type == "coupled":
    model = CoupledRNN(
        input_size=config["input_size"],
        pop1_size=config["pop1_size"],
        pop2_size=config["pop2_size"],
        output_size=config["num_place_cells"],
        alpha1=config["alpha1"],
        alpha2=config["alpha2"],
        activation=getattr(nn, config["activation"]),
        output_from=config["output_from"],
    )

    rnn_lightning = CoupledRNNLightning.load_from_checkpoint(
        checkpoint_files[0],
        model=model,
        learning_rate=config["learning_rate"],
        weight_decay=config["weight_decay"],
        step_size=config["step_size"],
        gamma=config["gamma"],
    )

model = rnn_lightning.model
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
model.eval()

print(f"Loaded model from run: {run_id}")
print(f"Model config: {config_path}")
print(f"Device: {device}")
# Out:
# Loading Lightning checkpoint from: logs/checkpoints/vanilla_20250821_003413/best-model-epoch=97-val_loss=6.052.ckpt
# Loaded model from run: 20250821_003413
# Model config: logs/checkpoints/vanilla_20250821_003413/config_20250821_003413.yaml
# Device: cuda

# %% [markdown]
# ## Visualize the loss curves

# %%
from pirnns.analysis import plot_loss_curves

plot_loss_curves(
    loss_file=f"{run_dir}/training_losses.json",
    title=f"Training Progress - Run {run_id}",
    log_x=True,
    log_y=True,
)
# Out:
# Loaded loss data from: logs/checkpoints/vanilla_20250821_003413/training_losses.json
# Training epochs: 99
# Initial train loss: 6.4953
# Final train loss: 6.0520
# Initial val loss: 6.3855
# Final val loss: 6.0525
# Best val loss: 6.051881 at epoch 97

# %% [markdown]
# ## Load evaluation datamodule

# %%
from datamodule import PathIntegrationDataModule

num_trajectories = 10000
batch_size = 1

eval_datamodule = PathIntegrationDataModule(
    num_trajectories=num_trajectories,
    batch_size=batch_size,
    num_workers=1,
    train_val_split=0.0,
    velocity_representation=config["velocity_representation"],
    dt=config["dt"],
    num_time_steps=config["num_time_steps"],
    arena_size=config["arena_size"],  # Changed from arena_L
    speed_scale=config["speed_scale"],  # Changed from mu_speed
    sigma_speed=config["sigma_speed"],
    tau_vel=config["tau_vel"],
    sigma_rotation=config["sigma_rotation"],
    border_region=config["border_region"],
    num_place_cells=config["num_place_cells"],
    place_cell_rf=config["place_cell_rf"],
    surround_scale=config["surround_scale"],
    DoG=config["DoG"],
    trajectory_type=config["trajectory_type"],
    place_cell_layout=config["place_cell_layout"],
)

eval_datamodule.setup()

eval_loader = eval_datamodule.val_dataloader()

print(f"Number of validation batches: {len(eval_loader)}")
print(f"Validation dataset size: {len(eval_datamodule.val_dataset)}")
# Out:
# Number of validation batches: 10000
# Validation dataset size: 10000

# %% [markdown]
# ## Visualize hidden unit activations over space

# %%
from pirnns.analysis.spatial import SpatialAnalyzer

spatial = SpatialAnalyzer(
    model=model,
    device=device,
    model_type=model_type,
    population_to_visualize="pop1",
)

spatial.compute_rate_maps(
    eval_loader=eval_loader,
    arena_size=config["arena_size"],
    bin_size=0.05,
    num_trajectories=10000,
    min_occupancy=10,
).plot_rate_maps(num_units=16, selection_method="spatial_info").plot_occupancy_map();
# Out:
# Computing spatial rate maps using 10000 trajectories...
# Spatial grid: 44 x 44 bins of size 0.05
# Hidden units to analyze: 4096
# Processed 1/10000 trajectories...
# Processed 51/10000 trajectories...
# Processed 101/10000 trajectories...
# Processed 151/10000 trajectories...
# Processed 201/10000 trajectories...
# Processed 251/10000 trajectories...
# Processed 301/10000 trajectories...
# Processed 351/10000 trajectories...
# Processed 401/10000 trajectories...
# Processed 451/10000 trajectories...
# Processed 501/10000 trajectories...
# Processed 551/10000 trajectories...
# Processed 601/10000 trajectories...
# Processed 651/10000 trajectories...
# Processed 701/10000 trajectories...
# Processed 751/10000 trajectories...
# Processed 801/10000 trajectories...
# Processed 851/10000 trajectories...
# Processed 901/10000 trajectories...
# Processed 951/10000 trajectories...
# Processed 1001/10000 trajectories...
# Processed 1051/10000 trajectories...
# Processed 1101/10000 trajectories...
# Processed 1151/10000 trajectories...
# Processed 1201/10000 trajectories...
# Processed 1251/10000 trajectories...
# Processed 1301/10000 trajectories...
# Processed 1351/10000 trajectories...
# Processed 1401/10000 trajectories...
# Processed 1451/10000 trajectories...
# Processed 1501/10000 trajectories...
# Processed 1551/10000 trajectories...
# Processed 1601/10000 trajectories...
# Processed 1651/10000 trajectories...
# Processed 1701/10000 trajectories...
# Processed 1751/10000 trajectories...
# Processed 1801/10000 trajectories...
# Processed 1851/10000 trajectories...
# Processed 1901/10000 trajectories...
# Processed 1951/10000 trajectories...
# Processed 2001/10000 trajectories...
# Processed 2051/10000 trajectories...
# Processed 2101/10000 trajectories...
# Processed 2151/10000 trajectories...
# Processed 2201/10000 trajectories...
# Processed 2251/10000 trajectories...
# Processed 2301/10000 trajectories...
# Processed 2351/10000 trajectories...
# Processed 2401/10000 trajectories...
# Processed 2451/10000 trajectories...
# Processed 2501/10000 trajectories...
# Processed 2551/10000 trajectories...
# Processed 2601/10000 trajectories...
# Processed 2651/10000 trajectories...
# Processed 2701/10000 trajectories...
# Processed 2751/10000 trajectories...
# Processed 2801/10000 trajectories...
# Processed 2851/10000 trajectories...
# Processed 2901/10000 trajectories...
# Processed 2951/10000 trajectories...
# Processed 3001/10000 trajectories...
# Processed 3051/10000 trajectories...
# Processed 3101/10000 trajectories...
# Processed 3151/10000 trajectories...
# Processed 3201/10000 trajectories...
# Processed 3251/10000 trajectories...
# Processed 3301/10000 trajectories...
# Processed 3351/10000 trajectories...
# Processed 3401/10000 trajectories...
# Processed 3451/10000 trajectories...
# Processed 3501/10000 trajectories...
# Processed 3551/10000 trajectories...
# Processed 3601/10000 trajectories...
# Processed 3651/10000 trajectories...
# Processed 3701/10000 trajectories...
# Processed 3751/10000 trajectories...
# Processed 3801/10000 trajectories...
# Processed 3851/10000 trajectories...
# Processed 3901/10000 trajectories...
# Processed 3951/10000 trajectories...
# Processed 4001/10000 trajectories...
# Processed 4051/10000 trajectories...
# Processed 4101/10000 trajectories...
# Processed 4151/10000 trajectories...
# Processed 4201/10000 trajectories...
# Processed 4251/10000 trajectories...
# Processed 4301/10000 trajectories...
# Processed 4351/10000 trajectories...
# Processed 4401/10000 trajectories...
# Processed 4451/10000 trajectories...
# Processed 4501/10000 trajectories...
# Processed 4551/10000 trajectories...
# Processed 4601/10000 trajectories...
# Processed 4651/10000 trajectories...
# Processed 4701/10000 trajectories...
# Processed 4751/10000 trajectories...
# Processed 4801/10000 trajectories...
# Processed 4851/10000 trajectories...
# Processed 4901/10000 trajectories...
# Processed 4951/10000 trajectories...
# Processed 5001/10000 trajectories...
# Processed 5051/10000 trajectories...
# Processed 5101/10000 trajectories...
# Processed 5151/10000 trajectories...
# Processed 5201/10000 trajectories...
# Processed 5251/10000 trajectories...
# Processed 5301/10000 trajectories...
# Processed 5351/10000 trajectories...
# Processed 5401/10000 trajectories...
# Processed 5451/10000 trajectories...
# Processed 5501/10000 trajectories...
# Processed 5551/10000 trajectories...
# Processed 5601/10000 trajectories...
# Processed 5651/10000 trajectories...
# Processed 5701/10000 trajectories...
# Processed 5751/10000 trajectories...
# Processed 5801/10000 trajectories...
# Processed 5851/10000 trajectories...
# Processed 5901/10000 trajectories...
# Processed 5951/10000 trajectories...
# Processed 6001/10000 trajectories...
# Processed 6051/10000 trajectories...
# Processed 6101/10000 trajectories...
# Processed 6151/10000 trajectories...
# Processed 6201/10000 trajectories...
# Processed 6251/10000 trajectories...
# Processed 6301/10000 trajectories...
# Processed 6351/10000 trajectories...
# Processed 6401/10000 trajectories...
# Processed 6451/10000 trajectories...
# Processed 6501/10000 trajectories...
# Processed 6551/10000 trajectories...
# Processed 6601/10000 trajectories...
# Processed 6651/10000 trajectories...
# Processed 6701/10000 trajectories...
# Processed 6751/10000 trajectories...
# Processed 6801/10000 trajectories...
# Processed 6851/10000 trajectories...
# Processed 6901/10000 trajectories...
# Processed 6951/10000 trajectories...
# Processed 7001/10000 trajectories...
# Processed 7051/10000 trajectories...
# Processed 7101/10000 trajectories...
# Processed 7151/10000 trajectories...
# Processed 7201/10000 trajectories...
# Processed 7251/10000 trajectories...
# Processed 7301/10000 trajectories...
# Processed 7351/10000 trajectories...
# Processed 7401/10000 trajectories...
# Processed 7451/10000 trajectories...
# Processed 7501/10000 trajectories...
# Processed 7551/10000 trajectories...
# Processed 7601/10000 trajectories...
# Processed 7651/10000 trajectories...
# Processed 7701/10000 trajectories...
# Processed 7751/10000 trajectories...
# Processed 7801/10000 trajectories...
# Processed 7851/10000 trajectories...
# Processed 7901/10000 trajectories...
# Processed 7951/10000 trajectories...
# Processed 8001/10000 trajectories...
# Processed 8051/10000 trajectories...
# Processed 8101/10000 trajectories...
# Processed 8151/10000 trajectories...
# Processed 8201/10000 trajectories...
# Processed 8251/10000 trajectories...
# Processed 8301/10000 trajectories...
# Processed 8351/10000 trajectories...
# Processed 8401/10000 trajectories...
# Processed 8451/10000 trajectories...
# Processed 8501/10000 trajectories...
# Processed 8551/10000 trajectories...
# Processed 8601/10000 trajectories...
# Processed 8651/10000 trajectories...
# Processed 8701/10000 trajectories...
# Processed 8751/10000 trajectories...
# Processed 8801/10000 trajectories...
# Processed 8851/10000 trajectories...
# Processed 8901/10000 trajectories...
# Processed 8951/10000 trajectories...
# Processed 9001/10000 trajectories...
# Processed 9051/10000 trajectories...
# Processed 9101/10000 trajectories...
# Processed 9151/10000 trajectories...
# Processed 9201/10000 trajectories...
# Processed 9251/10000 trajectories...
# Processed 9301/10000 trajectories...
# Processed 9351/10000 trajectories...
# Processed 9401/10000 trajectories...
# Processed 9451/10000 trajectories...
# Processed 9501/10000 trajectories...
# Processed 9551/10000 trajectories...
# Processed 9601/10000 trajectories...
# Processed 9651/10000 trajectories...
# Processed 9701/10000 trajectories...
# Processed 9751/10000 trajectories...
# Processed 9801/10000 trajectories...
# Processed 9851/10000 trajectories...
# Processed 9901/10000 trajectories...
# Processed 9951/10000 trajectories...
# Data collection complete. Total trajectories: 10000
# Rate maps created. Bins with sufficient data: 1936/1936
# Selected top 16 units by spatial information

# %% [markdown]
# ## Principal Component Analysis
#
# Compare with untrained model.

# %%
from pirnns.analysis.dynamics import DynamicsAnalyzer

if model_type == "vanilla":
    from pirnns.rnns.rnn import RNN
    import torch.nn as nn

    untrained_model = RNN(
        input_size=config["input_size"],
        hidden_size=config["hidden_size"],
        output_size=config["num_place_cells"],
        alpha=config["alpha"],
        activation=getattr(nn, config["activation"]),
    )
elif model_type == "coupled":
    from pirnns.rnns.coupled_rnn import CoupledRNN
    import torch.nn as nn

    untrained_model = CoupledRNN(
        input_size=config["input_size"],
        pop1_size=config["pop1_size"],
        pop2_size=config["pop2_size"],
        output_size=config["num_place_cells"],
        alpha1=config["alpha1"],
        alpha2=config["alpha2"],
        activation=getattr(nn, config["activation"]),
        output_from=config["output_from"],
    )

untrained_model.to(device)
untrained_model.eval()

dynamics = (
    DynamicsAnalyzer(
        trained_model=model,
        untrained_model=untrained_model,
        device=device,
        model_type=model_type,
        population_to_visualize="pop1",
    )
    .compute_hidden_states(eval_loader=eval_loader, num_batches=1000)
    .compute_pca(n_components=100)
    .plot_pca_spectrum()
    .plot_2d_pca_trajectories()
)
# Out:
# Computing hidden states from 1000 batches...
# Processed batch 1/1000
# Processed batch 101/1000
# Processed batch 201/1000
# Processed batch 301/1000
# Processed batch 401/1000
# Processed batch 501/1000
# Processed batch 601/1000
# Processed batch 701/1000
# Processed batch 801/1000
# Processed batch 901/1000
# Hidden states computed:
#   Trained shape: torch.Size([1000, 20, 4096])
#   Untrained shape: torch.Size([1000, 20, 4096])
# Computing PCA with 100 components...
# Data shapes for PCA:
#   Trained: torch.Size([20000, 4096])
#   Untrained: torch.Size([20000, 4096])
#   Ratio (samples/features): 4.88
# PCA completed:
#   Trained variance explained: 98.04%
#   Untrained variance explained: 97.94%
# === PCA Spectrum Analysis for Vanilla ===
# First 10 components (Trained):   [0.17084234 0.14171974 0.11926285 0.09981325 0.07653645 0.04480378
#  0.03773692 0.03312194 0.0245954  0.01775305]
# First 10 components (Untrained): [0.31007427 0.29307234 0.14822042 0.04586187 0.02962821 0.02461609
#  0.02300471 0.01344332 0.00868154 0.00673569]
#
# Variance explained by first N components:
#    1 components: Trained=0.171, Untrained=0.310
#    2 components: Trained=0.313, Untrained=0.603
#    5 components: Trained=0.608, Untrained=0.827
#   10 components: Trained=0.766, Untrained=0.903
#   20 components: Trained=0.878, Untrained=0.941
#
# Effective dimensionality (95% variance):
#   Trained:   40 components
#   Untrained: 25 components
#
# First PC dominance:
#   Trained PC1 explains 17.1% of variance
#   Untrained PC1 explains 31.0% of variance
#   → Trained model shows structured low-dimensional dynamics
#   → Untrained model shows some structure (unexpected)
